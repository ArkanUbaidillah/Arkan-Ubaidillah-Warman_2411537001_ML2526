# %% [markdown]
# <a href="https://colab.research.google.com/github/ArkanUbaidillah/Arkan-Ubaidillah-Warman_2411537001_ML2526/blob/main/Praktikum2/NaiveBayesTugas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
dataset_url = 'https://raw.githubusercontent.com/ArkanUbaidillah/Arkan-Ubaidillah-Warman_2411537001_ML2526/refs/heads/main/Praktikum2/Breast_cancer_data_cae7db121c99c2dfb709598afde3ccfe.csv'
data = pd.read_csv(dataset_url)
data.head()
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    diagnosis
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# Memisahkan fitur dan target
X = data.drop(columns=['diagnosis'])
y = data['diagnosis']

# %%
# Membagi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Membuat dan melatih model Gaussian Naive Bayes
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# Melakukan prediksi
prediksi = model.predict(X_test)

# %%
# Evaluasi model
akurasi = accuracy_score(y_test, prediksi)
f1 = f1_score(y_test, prediksi)

print("Akurasi =", akurasi)
print("F1-Score =", f1)
# Out:
# Akurasi = 0.9298245614035088
# F1-Score = 0.9459459459459459

# %%
# Membuat confusion matrix
cm = confusion_matrix(y_test, prediksi)

# %%
# Visualisasi confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='viridis')

plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.title("Confusion Matrix")

plt.show()
